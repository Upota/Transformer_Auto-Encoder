# %% [markdown]
# 기존 교사 강요 이용한 모델
# 구글 코랩에서 학습

# %%
# !git clone https://github.com/Upota/Transformer_Auto-Encoder.git
# %cd /content/Transformer_Auto-Encoder/Prediction/TeacherForcing_ver.1/
# Out:
# Cloning into 'Transformer_Auto-Encoder'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 50 (delta 19), reused 39 (delta 10), pack-reused 0
# Unpacking objects: 100% (50/50), done.
# /content/Transformer_Auto-Encoder/Prediction/TeacherForcing_ver.1

# %%
# set up logging
import logging
logging.basicConfig(
        format="%(asctime)s - %(levelname)s - %(name)s - %(message)s",
        datefmt="%m/%d/%Y %H:%M:%S",
        level=logging.INFO,
)

# %%
# make deterministic
from utils import set_seed
set_seed(42)

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Denoising Signal

# %% [markdown]
# 1. $$ sin(t) + \epsilon $$
# 2. $$ \sum^{n}{a sin(bt + c)} + \epsilon $$

# %% [markdown]
# ## Data generation

# %% [markdown]
# ### Data 1

# %%
# set parameters
block_size = 128

n_in = 1
n_sample = 51200
n_valid = 256

# %%
# generate sequential sine signal
x_interval = 0.09
sin_x = np.linspace(0, x_interval * n_sample, num=n_sample)
pure_sin = np.sin(sin_x)
noisy_sin = pure_sin + 0.1 * np.random.randn(pure_sin.shape[0])

# %%
pure = pure_sin[0:500]
plt.plot(range(len(pure)), pure)

# %%
noisy = noisy_sin[0:500]
plt.plot(range(len(noisy)), noisy)

# %%
class SinDataset(Dataset): # build custom dataset
    
    def __init__(self, x, y, block_size):
        self.block_size = block_size
        self.x = x # noisy_sin
        self.y = y # pure_sin
    
    def __getitem__(self, idx):
        # grab a chunk of (block_size + 1) elements from the data
        noisy_chunk = self.x[idx:idx + self.block_size + 1]
        pure_chunk = self.y[idx:idx + self.block_size + 1]
    
        x = torch.tensor(noisy_chunk[:-1], dtype=torch.float)
        y = torch.tensor(pure_chunk[1:], dtype=torch.float)
        return x, y
    
    def __len__(self):
        return len(self.x) - self.block_size

# %%
train_dataset1 = SinDataset(noisy_sin, pure_sin, block_size)
start_idx = 150
valid_dataset1 = SinDataset(noisy_sin[start_idx:start_idx + n_valid],
                            pure_sin[start_idx:start_idx + n_valid], block_size)

# %% [markdown]
# ### Data 2

# %%
# generate sequential complex sine signal
x_interval = 0.2
sin_x = np.linspace(0, x_interval * n_sample, num=n_sample)
sin_1 = np.sin(sin_x) # sin(t)
sin_2 = 1.5 * np.sin(0.5 * sin_x + 0.3 * np.pi) # 1.5sin(t + 0.3pi)
pure_sin = sin_1 + sin_2
noisy_sin = pure_sin + 0.2 * np.random.randn(pure_sin.shape[0])

# %%
pure = pure_sin[0:128]
plt.plot(range(len(pure)), pure)

# %%
noisy = noisy_sin[0:128]
plt.plot(range(len(noisy)), noisy)

# %%
train_dataset2 = SinDataset(noisy_sin, pure_sin, block_size)
start_idx = 150
valid_dataset2 = SinDataset(noisy_sin[start_idx:start_idx + n_valid],
                            pure_sin[start_idx:start_idx + n_valid], block_size)

# %% [markdown]
# ## Model

# %%
from model import TAE, TAEConfig
mconf = TAEConfig(n_in, block_size,
                 n_layer=2, n_head=4, n_embd=128)
model = TAE(mconf)
# Out:
# 08/02/2021 12:33:20 - INFO - model - number of parameters: 9.265920e+05

# %%
import gc
gc.collect()
# Out:
# 81

# %%
from pathlib import Path

PATH = Path("model")
FILENAME = "predict_data2" + ".ckpt"
ckpt_path = PATH / FILENAME
# ckpt_path = None
if ckpt_path is not None and ckpt_path.exists():
    print("load")
    model.load_state_dict(torch.load(ckpt_path))

# %% [markdown]
# ## Training

# %%
from trainer import Trainer, TrainerConfig
tconf = TrainerConfig(max_epochs=101, batch_size=256, learning_rate=6e-4,
                     lr_decay = True, ckpt_path=ckpt_path,
                     num_workers=2)
trainer = Trainer(model, train_dataset2, valid_dataset2, tconf)
trainer.train()
# Out:
# epoch 1 iter 199: train loss 0.03320. lr 6.000000e-04: 100%|██████████| 200/200 [00:37<00:00,  5.37it/s]
# 08/02/2021 12:35:31 - INFO - trainer - test loss: 0.036479
# 08/02/2021 12:35:31 - INFO - trainer - saving model/predict_data2.ckpt
# epoch 2 iter 199: train loss 0.03028. lr 5.998549e-04: 100%|██████████| 200/200 [00:37<00:00,  5.40it/s]
# 08/02/2021 12:36:08 - INFO - trainer - test loss: 0.028832
# 08/02/2021 12:36:08 - INFO - trainer - saving model/predict_data2.ckpt
# epoch 3 iter 199: train loss 0.02646. lr 5.994197e-04: 100%|██████████| 200/200 [00:36<00:00,  5.42it/s]
# 08/02/2021 12:36:45 - INFO - trainer - test loss: 0.023231
# 08/02/2021 12:36:45 - INFO - trainer - saving model/predict_data2.ckpt
# epoch 4 iter 199: train loss 0.02446. lr 5.986948e-04: 100%|██████████| 200/200 [00:36<00:00,  5.41it/s]
# 08/02/2021 12:37:22 - INFO - trainer - test loss: 0.023084
# 08/02/2021 12:37:22 - INFO - trainer - saving model/predict_data2.ckpt
# epoch 5 iter 199: train loss 0.02215. lr 5.976810e-04: 100%|██████████| 200/200 [00:36<00:00,  5.42it/s]
# 08/02/2021 12:37:59 - INFO - trainer - test loss: 0.019729
# 08/02/2021 12:37:59 - INFO - trainer - saving model/predict_data2.ckpt
# epoch 6 iter 199: train loss 0.02106. lr 5.963791e-04: 100%|██████████| 200/200 [00:37<00:00,  5.39it/s]
# 08/02/2021 12:38:37 - INFO - trainer - test loss: 0.018630
# 08/02/2021 12:38:37 - INFO - trainer - saving model/predict_data2.ckpt
# epoch 7 iter 199: train loss 0.02233. lr 5.947906e-04: 100%|██████████| 200/200 [00:37<00:00,  5.38it/s]
# 08/02/2021 12:39:14 - INFO - trainer - test loss: 0.019388
# epoch 8 iter 199: train loss 0.01984. lr 5.929168e-04: 100%|██████████| 200/200 [00:37<00:00,  5.40it/s]
# 08/02/2021 12:39:51 - INFO - trainer - test loss: 0.016890
# 08/02/2021 12:39:51 - INFO - trainer - saving model/predict_data2.ckpt
# epoch 9 iter 199: train loss 0.01930. lr 5.907597e-04: 100%|██████████| 200/200 [00:37<00:00,  5.39it/s]
# 08/02/2021 12:40:29 - INFO - trainer - test loss: 0.017169
# epoch 10 iter 199: train loss 0.02015. lr 5.883213e-04: 100%|██████████| 200/200 [00:37<00:00,  5.40it/s]
# 08/02/2021 12:41:06 - INFO - trainer - test loss: 0.016454
# 08/02/2021 12:41:06 - INFO - trainer - saving model/predict_data2.ckpt
# epoch 11 iter 199: train loss 0.01797. lr 5.856039e-04: 100%|██████████| 200/200 [00:37<00:00,  5.40it/s]
# 08/02/2021 12:41:43 - INFO - trainer - test loss: 0.015396
# 08/02/2021 12:41:43 - INFO - trainer - saving model/predict_data2.ckpt
# epoch 12 iter 199: train loss 0.01835. lr 5.826103e-04: 100%|██████████| 200/200 [00:37<00:00,  5.40it/s]
# 08/02/2021 12:42:20 - INFO - trainer - test loss: 0.014744
# 08/02/2021 12:42:20 - INFO - trainer - saving model/predict_data2.ckpt
# epoch 13 iter 199: train loss 0.01787. lr 5.793432e-04: 100%|██████████| 200/200 [00:37<00:00,  5.39it/s]
# 08/02/2021 12:42:58 - INFO - trainer - test loss: 0.015721
# epoch 14 iter 199: train loss 0.01823. lr 5.758059e-04: 100%|██████████| 200/200 [00:37<00:00,  5.39it/s]
# 08/02/2021 12:43:35 - INFO - trainer - test loss: 0.014854
# epoch 15 iter 199: train loss 0.01827. lr 5.720018e-04: 100%|██████████| 200/200 [00:37<00:00,  5.39it/s]
# 08/02/2021 12
lr 6.000000e-05: 100%|██████████| 200/200 [00:37<00:00,  5.38it/s]
# 08/02/2021 13:29:31 - INFO - trainer - test loss: 0.010461
# epoch 89 iter 199: train loss 0.01258. lr 6.000000e-05: 100%|██████████| 200/200 [00:36<00:00,  5.41it/s]
# 08/02/2021 13:30:08 - INFO - trainer - test loss: 0.010346
# epoch 90 iter 199: train loss 0.01218. lr 6.000000e-05: 100%|██████████| 200/200 [00:37<00:00,  5.39it/s]
# 08/02/2021 13:30:45 - INFO - trainer - test loss: 0.010586
# epoch 91 iter 199: train loss 0.01191. lr 6.000000e-05: 100%|██████████| 200/200 [00:36<00:00,  5.41it/s]
# 08/02/2021 13:31:22 - INFO - trainer - test loss: 0.010519
# epoch 92 iter 199: train loss 0.01225. lr 6.000000e-05: 100%|██████████| 200/200 [00:36<00:00,  5.41it/s]
# 08/02/2021 13:32:00 - INFO - trainer - test loss: 0.010404
# epoch 93 iter 199: train loss 0.01221. lr 6.000000e-05: 100%|██████████| 200/200 [00:37<00:00,  5.40it/s]
# 08/02/2021 13:32:37 - INFO - trainer - test loss: 0.010359
# epoch 94 iter 199: train loss 0.01289. lr 6.000000e-05: 100%|██████████| 200/200 [00:37<00:00,  5.39it/s]
# 08/02/2021 13:33:14 - INFO - trainer - test loss: 0.010749
# epoch 95 iter 199: train loss 0.01237. lr 6.000000e-05: 100%|██████████| 200/200 [00:36<00:00,  5.42it/s]
# 08/02/2021 13:33:51 - INFO - trainer - test loss: 0.010505
# epoch 96 iter 199: train loss 0.01263. lr 6.000000e-05: 100%|██████████| 200/200 [00:37<00:00,  5.40it/s]
# 08/02/2021 13:34:29 - INFO - trainer - test loss: 0.010494
# epoch 97 iter 199: train loss 0.01190. lr 6.000000e-05: 100%|██████████| 200/200 [00:36<00:00,  5.41it/s]
# 08/02/2021 13:35:06 - INFO - trainer - test loss: 0.010807
# epoch 98 iter 199: train loss 0.01155. lr 6.000000e-05: 100%|██████████| 200/200 [00:37<00:00,  5.39it/s]
# 08/02/2021 13:35:43 - INFO - trainer - test loss: 0.010477
# epoch 99 iter 199: train loss 0.01208. lr 6.000000e-05: 100%|██████████| 200/200 [00:37<00:00,  5.40it/s]
# 08/02/2021 13:36:20 - INFO - trainer - test loss: 0.010561
# epoch 100 iter 199: train loss 0.01231. lr 6.000000e-05: 100%|██████████| 200/200 [00:36<00:00,  5.41it/s]
# 08/02/2021 13:36:58 - INFO - trainer - test loss: 0.010472
# epoch 101 iter 199: train loss 0.01298. lr 6.000000e-05: 100%|██████████| 200/200 [00:36<00:00,  5.41it/s]
# 08/02/2021 13:37:35 - INFO - trainer - test loss: 0.010498

# %%
plt.plot(range(len(trainer.train_losses)), trainer.train_losses, label="Training loss")
plt.plot(range(len(trainer.validation_losses)), trainer.validation_losses, label="Validation loss")

# %% [markdown]
# ## Testing

# %%
from utils import sample
start_idx = 500
x = torch.tensor(noisy_sin[start_idx : start_idx + block_size], dtype=torch.float).to(trainer.device).view(1, block_size)
y = sample(model, x, block_size * 2)[0]
y = y.cpu().numpy()

# %%
plt.plot(range(len(y)), y)

# %%
pure = pure_sin[start_idx : start_idx + 3 * block_size]
noisy = noisy_sin[start_idx : start_idx + 3 * block_size]

plt.figure(figsize=(10,5))
plt.subplot(411)
plt.plot(range(0, 3 * block_size), pure, label='pure')

plt.subplot(412)
plt.plot(range(0, 3 * block_size), noisy, label='noisy')

plt.subplot(413)
plt.plot(range(len(y)), y, label='prediction')

plt.subplot(414)
plt.plot(range(3 * block_size), pure, label='pure')
plt.plot(range(3 * block_size), noisy, label='noisy')
plt.plot(range(len(y)), y, label='prediction')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(17,10))
plt.plot(range(3 * block_size), noisy, label='noisy')
# plt.plot(range(block_size, len(y)), y[block_size:], label='prediction')
plt.plot(range(len(y)), y, label='prediction')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(17,10))
plt.plot(range(3 * block_size), pure, label='pure')
# plt.plot(range(block_size, len(y)), y[block_size:], label='prediction')
plt.plot(range(len(y)), y, label='prediction')
plt.legend()
plt.show()
